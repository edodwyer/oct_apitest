# %%
import datetime as dt
import pandas as pd
import pickle
import numpy as np
import app_fcns as fcns
from dash import Dash, html, dcc
import plotly.express as px
from plotly.subplots import make_subplots

# %%
# Generate parameters

# Get defaults:
# dStart,Bat_capacity,ch_max,Eff,agile_version = import_user_inputs()

# Start date:
dStart='29-Sep-2022 00:00'

# 0:'AGILE-18-02-21', 1:'AGILE-22-07-22', 2:'AGILE-22-08-31', Fixed:'VAR-19-04-12'
agile_version = 2


# Battery parameters:

# Capacity of battery in kWh:
Bat_capacity = 13 

# Max charge/discharge power in kW:
ch_max = 3

# Round-trip efficiency:
Eff = 0.9 


user_params = dict()
user_params['dStart'] = dStart
user_params['Bat_capacity'] = Bat_capacity
user_params['ch_max'] = ch_max
user_params['Eff'] = Eff
user_params['agile_version'] = agile_version

params,batparams,tindex = fcns.get_params(user_params)

# %%
# Pull price data from Octopus API

tariffs = fcns.get_tariffs(params)

# %%
# Pull demand data from AWS RDS

dem_df =  fcns.get_demand(params)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\envs\oct_test\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# ~\anaconda3\envs\oct_test\lib\socket.py in create_connection(address, timeout, source_address)
#     844         try:
# --> 845             raise err
#     846         finally:
#
# ~\anaconda3\envs\oct_test\lib\socket.py in create_connection(address, timeout, source_address)
#     832                 sock.bind(source_address)
# --> 833             sock.connect(sa)
#     834             # Break explicitly a reference cycle
#
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144             except:
# --> 145                 with util.safe_reraise():
#     146                     self._dec_overflow()
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     207         try:
# --> 208             raise exception
#     209         finally:
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     664         except Exception as e:
# --> 665             with util.safe_reraise():
#     666                 pool.logger.debug("Error on connect(): %s", e)
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     207         try:
# --> 208             raise exception
#     209         finally:
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     596         # inherits the docstring from interfaces.Dialect.connect
# --> 597         return self.dbapi.connect(*cargs, **cparams)
#     598
#
# ~\anaconda3\envs\oct_test\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     352         else:
# --> 353             self.connect()
#     354
#
# ~\anaconda3\envs\oct_test\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#
# OperationalError: (2003, "Can't connect to MySQL server on 'oct-comparison.cuw2mwjgjoy7.eu-west-2.rds.amazonaws.com' (timed out)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15240\400933081.py in <module>
#       1 # Pull demand data from AWS RDS
#       2
# ----> 3 dem_df =  fcns.get_demand(params)
#
# ~\oct_apitest\app_fcns.py in get_demand(params)
#      64 def get_demand(params):
#      65
# ---> 66     dem0 = get_sql_dat(params['dStart'],params['dEnd'])
#      67     dem_df_full = dem0.tz_localize(tz='UTC')#[params['dStart']:params['dEnd']]
#      68     dem_df = dem_df_full['elec_demand_W'].resample(params['samp']).mean()
#
# ~\oct_apitest\read_from_rds.py in get_sql_dat(dStart, dEnd)
#      14     sqlEngine = create_engine('mysql+pymysql://'+user+':'+password+'@'+address+dbschem, pool_recycle=3306)
#      15
# ---> 16     synth_demand=pd.read_sql("SELECT * FROM SyntheticDemand where DateTime between "+f"'{dStart}'"+" and "+f"'{dEnd}'", con=sqlEngine,index_col='DateTime')
#      17
#      18     return synth_demand
#
# ~\anaconda3\envs\oct_test\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     591         )
#     592     else:
# --> 593         return pandas_sql.read_query(
#     594             sql,
#     595             index_col=index_col,
#
# ~\anaconda3\envs\oct_test\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1558         args = _convert_params(sql, params)
#    1559
# -> 1560         result = self.execute(*args)
#    1561         columns = result.keys()
#    1562
#
# ~\anaconda3\envs\oct_test\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1403     def execute(self, *args, **kwargs):
#    1404         """Simple passthrough to SQLAlchemy connectable"""
# -> 1405         return self.connectable.execution_options().execute(*args, **kwargs)
#    1406
#    1407     def read_table(
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     400         if not skip_warning:
#     401             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 402         return fn(*args, **kwargs)
#     403
#     404     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    3173
#    3174         """
# -> 3175         connection = self.connect(close_with_result=True)
#    3176         return connection.execute(statement, *multiparams, **params)
#    3177
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3232         """
#    3233
# -> 3234         return self._connection_cls(self, close_with_result=close_with_result)
#    3235
#    3236     @util.deprecated(
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3311
#    3312         """
# -> 3313         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3314
#    3315
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3281         except dialect.dbapi.Error as e:
#    3282             if connection is None:
# -> 3283                 Connection._handle_dbapi_exception_noconnection(
#    3284                     e, dialect, self
#    3285                 )
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2115             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2116         elif should_wrap:
# -> 2117             util.raise_(
#    2118                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2119             )
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206
#     207         try:
# --> 208             raise exception
#     209         finally:
#     210             # credit to
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3278         dialect = self.dialect
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#    3282             if connection is None:
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     308
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#     312     def _return_conn(self, record):
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     866     def _checkout(cls, pool, threadconns=None, fairy=None):
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#     870             fairy._pool = pool
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     474     @classmethod
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#     478             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     143                 return self._create_connection()
#     144             except:
# --> 145                 with util.safe_reraise():
#     146                     self._dec_overflow()
#     147         else:
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206
#     207         try:
# --> 208             raise exception
#     209         finally:
#     210             # credit to
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     254         """Called by subclasses to create a new ConnectionRecord."""
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#     258     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     369         self.__pool = pool
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#     373
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     663             self.fresh = True
#     664         except Exception as e:
# --> 665             with util.safe_reraise():
#     666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206
#     207         try:
# --> 208             raise exception
#     209         finally:
#     210             # credit to
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     659         try:
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#     663             self.fresh = True
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     588                     if connection is not None:
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#     592         creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\envs\oct_test\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     595     def connect(self, *cargs, **cparams):
#     596         # inherits the docstring from interfaces.Dialect.connect
# --> 597         return self.dbapi.connect(*cargs, **cparams)
#     598
#     599     def create_connect_args(self, url):
#
# ~\anaconda3\envs\oct_test\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# ~\anaconda3\envs\oct_test\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     662                 if DEBUG:
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#     666             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on 'oct-comparison.cuw2mwjgjoy7.eu-west-2.rds.amazonaws.com' (timed out)")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
    user = credentials.user
    password = credentials.password
    address= credentials.address
    dbschem = credentials.dbschem
    
#     'mysql://%s:%s@%s' % (USER, PASSWORD, HOST)
    sqlEngine = create_engine('mysql+pymysql://'+user+':'+password+'@'+address+dbschem, pool_recycle=3306)
    
    synth_demand=pd.read_sql("SELECT * FROM SyntheticDemand where DateTime between "+f"'{dStart}'"+" and "+f"'{dEnd}'", con=sqlEngine,index_col='DateTime')

# %%
# Simulate costs for one set of charging/discharging times

# Start charging at:
ch_start_hour=3

# Start discharging at:
dch_start_hour=14

res_df, cost_df = fcns.run_1_sim(params,batparams,tariffs,dem_df,tindex,ch_start_hour,dch_start_hour)

# %%
# Find best charging/disharging times

res_df,cost_df,bestsol,best_dch_start,best_ch_start = fcns.run_best_sim(params,batparams,tariffs,dem_df,tindex)

# %%
# Plot results using dash and plotly

from jupyter_plotly_dash import JupyterDash

app = JupyterDash(__name__)

dfa = pd.concat([tariffs['Agile'],tariffs['Fixed']],axis=1)
dfa.columns=['Agile','Fixed']
dfa=dfa.melt(var_name='tariff', value_name='value', ignore_index=False)

df1 = cost_df.cumsum()

subfig = make_subplots(specs=[[{"secondary_y": True}]])

fig = px.line(res_df, x=res_df.index, y=["Baseline_Grid","Grid"],color_discrete_sequence=px.colors.qualitative.Vivid)
figa = px.line(dfa, x=dfa.index, y=["value"],color='tariff',line_dash_sequence=['dot'],width=10)

figa.update_traces(yaxis="y2")

subfig.add_traces(fig.data + figa.data)
subfig.layout.xaxis.title="Time"
subfig.layout.yaxis.title="Power Consumption"
subfig.layout.yaxis2.title="price p/kWh"
subfig.layout.yaxis2.showgrid=False


bars=pd.DataFrame(data=[df1.iloc[-1].values],columns=df1.columns,index=['Total cost']).T


figures = [
            px.line(df1, x=df1.index, y=["Agile","Fixed"], title="Test",color_discrete_sequence=px.colors.qualitative.Vivid),
            px.bar(bars)
    ]

fig1 = make_subplots(rows=1, cols=len(figures)) 
fig1.layout.yaxis.title="Accumulated cost £"

for i, figure in enumerate(figures):
    for trace in range(len(figure["data"])):
        fig1.append_trace(figure["data"][trace], row=1, col=i+1)




app.layout = html.Div(children=[
    html.Div([        
        html.H1(children='Grid demand'),

        html.Div(children='''
            With and without battery+Agile.
        '''),

        dcc.Graph(
            id='f1',
            figure=subfig
        ),
    ]),


    html.Div([
        html.Div([
            html.H1(children='Cumulative cost'),

            html.Div(children='''
                With and without battery+Agile.
            '''),

            dcc.Graph(
                id='f2',
                figure=fig1
            ),
        ]),
    ]),    
])

app
# Out:
# <div>
#   <iframe src="/app/endpoints/66a33fa696bc4c6799cf8c401108410a/" width=800 height=600 frameborder="0"></iframe>
#   <hr/><a href="/app/endpoints/66a33fa696bc4c6799cf8c401108410a/" target="_new">Open in new window</a> for /app/endpoints/66a33fa696bc4c6799cf8c401108410a/
# </div>
